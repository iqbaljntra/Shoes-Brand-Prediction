# %% [markdown]
# # MODEL INFERANCE

# %% [markdown]
# # P2M2
#
# ### Name : Iqbal Janitra
#
# ### Batch : 003

# %% [markdown]
# # IMPORT LIBRARIES

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random
from keras import layers
from tensorflow.keras.preprocessing import image
from keras.callbacks import Callback
from keras.layers import Conv2D
from keras.backend import epsilon
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.layers import Conv2D

# %% [markdown]
# # LOAD MODEL

# %%
model = keras.models.load_model("bestmodelshoesprediction.h5")
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2023-02-11 21:22:30.172977: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-11 21:22:30.173517: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# # MODEL IFERANCE EVALUATION

# %%
# Custom function to load and predict label for the image
def predict(img_rel_path):
    # Import Image from the path with size of (300, 300)
    img = image.load_img(img_rel_path, target_size=(300, 300))

    # Convert Image to a numpy array
    img = image.img_to_array(img, dtype=np.uint8)

    # Scaling the Image Array values between 0 and 1
    img = np.array(img)/255.0

    # Plotting the Loaded Image
    plt.title("Loaded Image")
    plt.axis('off')
    plt.imshow(img.squeeze())
    plt.show()

    # Get the Predicted Label for the loaded Image
    p = model.predict(img[np.newaxis, ...])

    # Label array
    labels = {0: 'adidas', 1: 'converse', 2: 'nike'}

    print("\n\nMaximum Probability: ", np.max(p[0], axis=-1))
    predicted = labels[np.argmax(p[0], axis=-1)]
    print("Classified:", predicted, "\n\n")

    classes=[]
    prob=[]
    print("\n-------------------Individual Probability--------------------------------\n")

    for i,j in enumerate (p[0],0):
        print(labels[i].upper(),':',round(j*100,2),'%')
        classes.append(labels[i])
        prob.append(round(j*100,2))

# %% [markdown]
# # MODEL PREDICTION RESULT

# %% [markdown]
# ### Nike Prediction

# %%
predict('/Users/iqbaljanitra/Documents/PHASE 3/MILESTONE/MILESTONE 2/archive-6/train/nike/85.jpg')
# Out:
# 2023-02-11 21:22:38.484512: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-02-11 21:22:38.774482: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 1s 842ms/step
#
#
# Maximum Probability:  0.8415529
# Classified: nike
#
#
#
# -------------------Individual Probability--------------------------------
#
# ADIDAS : 24.58 %
# CONVERSE : 4.11 %
# NIKE : 84.16 %

# %%
predict('/Users/iqbaljanitra/Documents/PHASE 3/MILESTONE/MILESTONE 2/archive-6/train/nike/82.jpg')
# Out:
# 1/1 [==============================] - 0s 31ms/step
#
#
# Maximum Probability:  0.73763114
# Classified: nike
#
#
#
# -------------------Individual Probability--------------------------------
#
# ADIDAS : 19.69 %
# CONVERSE : 9.95 %
# NIKE : 73.76 %

# %%
predict('/Users/iqbaljanitra/Documents/PHASE 3/MILESTONE/MILESTONE 2/archive-6/train/nike/92.jpg')
# Out:
# 1/1 [==============================] - 0s 31ms/step
#
#
# Maximum Probability:  0.92933583
# Classified: nike
#
#
#
# -------------------Individual Probability--------------------------------
#
# ADIDAS : 13.86 %
# CONVERSE : 4.86 %
# NIKE : 92.93 %

# %% [markdown]
# ### Adidas Prediction

# %%
predict('/Users/iqbaljanitra/Documents/PHASE 3/MILESTONE/MILESTONE 2/archive-6/train/adidas/45.jpg')
# Out:
# 1/1 [==============================] - 0s 58ms/step
#
#
# Maximum Probability:  0.77643967
# Classified: adidas
#
#
#
# -------------------Individual Probability--------------------------------
#
# ADIDAS : 77.64 %
# CONVERSE : 11.94 %
# NIKE : 20.63 %

# %%
predict('/Users/iqbaljanitra/Documents/PHASE 3/MILESTONE/MILESTONE 2/archive-6/train/adidas/41.jpg')
# Out:
# 1/1 [==============================] - 0s 37ms/step
#
#
# Maximum Probability:  0.6621471
# Classified: adidas
#
#
#
# -------------------Individual Probability--------------------------------
#
# ADIDAS : 66.21 %
# CONVERSE : 6.22 %
# NIKE : 37.06 %

# %%
predict('/Users/iqbaljanitra/Documents/PHASE 3/MILESTONE/MILESTONE 2/archive-6/train/adidas/99.jpg')
# Out:
# 1/1 [==============================] - 0s 43ms/step
#
#
# Maximum Probability:  0.5703739
# Classified: adidas
#
#
#
# -------------------Individual Probability--------------------------------
#
# ADIDAS : 57.04 %
# CONVERSE : 35.28 %
# NIKE : 13.38 %

# %% [markdown]
# ### Converse Prediction

# %%
predict('/Users/iqbaljanitra/Documents/PHASE 3/MILESTONE/MILESTONE 2/archive-6/train/converse/64.jpg')
# Out:
# 1/1 [==============================] - 0s 30ms/step
#
#
# Maximum Probability:  0.8960886
# Classified: converse
#
#
#
# -------------------Individual Probability--------------------------------
#
# ADIDAS : 19.38 %
# CONVERSE : 89.61 %
# NIKE : 9.27 %

# %%
predict('/Users/iqbaljanitra/Documents/PHASE 3/MILESTONE/MILESTONE 2/archive-6/train/converse/62.jpg')
# Out:
# 1/1 [==============================] - 0s 35ms/step
#
#
# Maximum Probability:  0.83655083
# Classified: converse
#
#
#
# -------------------Individual Probability--------------------------------
#
# ADIDAS : 10.61 %
# CONVERSE : 83.66 %
# NIKE : 25.59 %

# %%
predict('/Users/iqbaljanitra/Documents/PHASE 3/MILESTONE/MILESTONE 2/archive-6/train/converse/61.jpg')
# Out:
# 1/1 [==============================] - 0s 34ms/step
#
#
# Maximum Probability:  0.730458
# Classified: converse
#
#
#
# -------------------Individual Probability--------------------------------
#
# ADIDAS : 24.92 %
# CONVERSE : 73.05 %
# NIKE : 12.28 %
